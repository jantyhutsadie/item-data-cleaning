# %%
import pandas as pd

# %%
df = pd.read_csv('files/customers-1000.csv')
df
# Out:
#      Index      Customer Id First Name Last Name                      Company  \
# 0        1  dE014d010c7ab0c     Andrew   Goodman                Stewart-Flynn
# 1        2  2B54172c8b65eC3      Alvin      Lane  Terry, Proctor and Lawrence
# 2        3  d794Dd48988d2ac      Jenna   Harding                 Bailey Group
# 3        4  3b3Aa4aCc68f3Be   Fernando      Ford                 Moss-Maxwell
# 4        5  D60df62ad2ae41E       Kara     Woods              Mccarthy-Kelley
# ..     ...              ...        ...       ...                          ...
# 995    996  FbcCaF483aFaFAE      Diana    Monroe                  Bass-Wilson
# 996    997  979c4D58Ae9a9cc      Jerry   Morales                   Pratt-King
# 997    998  D0DcF6a4BcefCc8     Tracie     Floyd     Holt, Wilson and Shields
# 998    999  90EE9CbbDa374E9       Paul    Barnes     Brown, Oliver and Haynes
# 999   1000  51732B5b2328015    Dominic     Duran                   Durham LLC
#
# ...

# %%
df_filtered = df[['Customer Id', 'First Name', 'Last Name', 'Email']]

df_filtered
# Out:
#          Customer Id First Name Last Name                          Email
# 0    dE014d010c7ab0c     Andrew   Goodman  marieyates@gomez-spencer.info
# 1    2B54172c8b65eC3      Alvin      Lane          alexandra86@mccoy.com
# 2    d794Dd48988d2ac      Jenna   Harding        justincurtis@pierce.org
# 3    3b3Aa4aCc68f3Be   Fernando      Ford            adeleon@hubbard.org
# 4    D60df62ad2ae41E       Kara     Woods          jesus90@roberson.info
# ..               ...        ...       ...                            ...
# 995  FbcCaF483aFaFAE      Diana    Monroe     cassidymercado@bonilla.com
# 996  979c4D58Ae9a9cc      Jerry   Morales        gavin13@logan-downs.com
# 997  D0DcF6a4BcefCc8     Tracie     Floyd         lowehailey@oconnor.org
# 998  90EE9CbbDa374E9       Paul    Barnes   hodgeseddie@hardin-wells.com
# 999  51732B5b2328015    Dominic     Duran         owarner@velasquez.info
#
# [1000 rows x 4 columns]
